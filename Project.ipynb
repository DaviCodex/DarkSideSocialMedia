# %% [markdown]
# # Resumen del proyecto
#
# En este proyecto busco analizar que patrones presentan las redes sociales para que nosotros las usemos mas y que imactos generan en nuestra prductividad.

# %%
import pandas as pd 
import matplotlib.pyplot as plot

path='./Time-Wasters on Social Media.csv'

df=pd.read_csv(path)

df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %% [markdown]
# # Pregunta 1:
#
# Que relacion existe entre la cantidad de videos vistos con la percepción de adiccion.
#
# Pra responder esta pregunta primero hay que aclarar que se considera como una percepcion de adiccion, es un indicador de 0  a 10, donde la persona se califica asi misma:
#
#     * Cero es nada adicto
#
#     * Diez es adicto
#
# Como se calcula la correlación lineal entre dos variables:
#
# ![image.png](attachment:image.png)
#
# Donde **X** sera la cantidad de videos vistos y **Y** la percepción de adicción

# %%
#Obtener informacion de las dos columnas 
#
lvl_adc=df['Addiction Level'].value_counts(sort=True)
lvl_adc.plot(kind="bar")
# Out:
# Addiction Level
# 2    248
# 5    228
# 0    180
# 3    159
# 1     60
# 7     55
# 4     36
# 6     34
# Name: count, dtype: int64

# %%
vid_views=df['Number of Videos Watched'].value_counts(sort=True, ascending=False)
vid_views.plot(kind="bar")
vid_views
# Out:
# Number of Videos Watched
# 15    32
# 39    28
# 31    28
# 17    27
# 27    27
# 1     25
# 49    25
# 18    24
# 20    24
# 28    24
# 23    24
# 29    24
# 4     23
# 45    23
# 10    23
# 48    22
# 47    22
# 8     21
# 32    21
# 36    21
# 9     21
# 3     21
# 34    21
# 44    21
# 21    21
# 14    20
# 30    20
# 22    20
# 40    20
# 16    20
# 46    19
# 37    18
# 26    18
# 19    18
# 41    18
# 25    17
# 35    17
# 13    17
# 24    16
# 42    16
# 7     16
# 43    16
# 6     16
# 2     15
# 38    15
# 5     14
# 12    14
# 33    14
# 11    13
# Name: count, dtype: int64
